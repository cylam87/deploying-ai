# %%
# %load_ext dotenv
# %dotenv ../../05_src/.secrets

# %% [markdown]
# # Deep Agents: Human-in-the-Loop Research Loop
#
# This notebook introduces `create_deep_agent()` from the `deepagents` package - a higher-level API that wraps the `StateGraph` + `ToolNode` pattern previously discussed and adds a permission layer on top. As compared to 07_1_llm_compiler, which is more suited for actual devs, the ready-to-use `deepagents` package makes it much easier for making simpler agents without many requirements or specifications.
#
# ## From StateGraph to `create_deep_agent()`
#
# Previously, we wired a `StateGraph` manually. `create_deep_agent()` handles that wiring internally:
#
# |  manual `StateGraph` |  `create_deep_agent()` |
# |---|---|
# | `StateGraph(MessagesState)` + `add_node` + `add_edge` + `compile()` | handled internally |
# | `ToolNode(tools)` | `tools=[internet_search]` |
# | No checkpointer | `checkpointer=MemorySaver()` |
# | No HITL - agent runs to completion | `permissions=[FilesystemPermission(...)]` pauses before writes |
# | - | Resume: `agent.invoke(Command(resume={...}), config)` |
#
# The key insight: **oversight is a property of agent construction, not graph wiring.** You don't add a human approval node - you declare a permission rule at construction time, and the framework pauses automatically when the rule triggers.
#
# ## What we'll build
#
# A research loop that:
# 1. Takes a topic from you
# 2. Searches the web via Tavily
# 3. **Pauses** before writing results to disk - showing you what it wants to save
# 4. Proceeds based on your approval or rejection
# 5. Assesses its own output quality regardless of what you decided
#
# **Prerequisites:**
# + Complete `05_2_langchain_agent.ipynb` before this notebook.
# + If you haven't done so already, sign up on Tavily and get a Tavily API key. Paste the key in your .secrets file.

# %%
import os
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain_tavily import TavilySearch
from deepagents import create_deep_agent, FilesystemPermission
from deepagents.backends import FilesystemBackend
from langgraph.checkpoint.memory import MemorySaver
from langgraph.types import Command
from langchain_core.messages import AIMessage
from IPython.display import Markdown, display

llm = init_chat_model(
    "openai:gpt-4o-mini",
    temperature=1,
    base_url='https://k7uffyg03f.execute-api.us-east-1.amazonaws.com/prod/openai/v1',
    api_key='any value',
    default_headers={"x-api-key": os.getenv('API_GATEWAY_KEY')}
)

display(Markdown(f"LLM ready: {llm is not None}"))
display(Markdown(f"API_GATEWAY_KEY loaded: {bool(os.getenv('API_GATEWAY_KEY'))}"))
display(Markdown(f"TAVILY_API_KEY loaded: {bool(os.getenv('TAVILY_API_KEY'))}"))
# Out:
# LLM ready: True
# API_GATEWAY_KEY loaded: True
# TAVILY_API_KEY loaded: True

# %% [markdown]
# ## Section 1 - Tool Definition
#
# `create_deep_agent()` accepts standard LangChain `@tool`-decorated functions - the same pattern from `tools_animals.py` and `tools_horoscope.py` in the course chat client. The agent infers the tool's schema from the function signature and docstring; no separate schema object is needed.
#
# We wrap `TavilySearch` in a thin `@tool` function so that LangGraph can recognize and use it as a tool.

# %%
@tool
def internet_search(query: str, max_results: int = 5) -> str:
    """Search the web for information on a topic. Returns a summary of the top results."""
    results = TavilySearch(max_results=max_results).invoke({"query": query})
    return str(results)

# %%
# Verify TAVILY_API_KEY is working before building the agent
test_result = internet_search.invoke({"query": "LangGraph human-in-the-loop 2024"})
print(test_result[:500])
# Out:
# {'query': 'LangGraph human-in-the-loop 2024', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.langchain.com/blog/making-it-easier-to-build-human-in-the-loop-agents-with-interrupt', 'title': 'Making it easier to build human-in-the-loop agents with interrupt', 'content': '# Making it easier to build human-in-the-loop agents with interrupt. This often makes it important to keep the human “in the loop” when building agents. From the start, we designed Lang

# %% [markdown]
# this test prints out the first 500 chars from the results of a google search for the query "LangGraph human-in-the-loop 2024"

# %% [markdown]
# ## Section 2 - Agent Construction with FilesystemPermission
#
# Three components work together to enable the permission gate:
#
# 1. **`FilesystemPermission(mode="interrupt")`** - fires *before any write hits disk*, including the agent's built-in `write_file` harness tool. The gate is filesystem-level, not tied to a specific tool name. `paths=["/**"]` means any path triggers it.
#
# 2. **`MemorySaver()`** - required for HITL. When the interrupt fires, the agent suspends mid-execution. `MemorySaver` preserves the full graph state so the `resume` call can reconstruct exactly where it stopped.
#
# 3. **`thread_id`** - the session key. The same `thread_id` must appear in both the initial `invoke()` and the `Command(resume=...)` call. Use a fresh `thread_id` for each independent demo run to avoid state collision between runs.

# %% [markdown]
# Add a [local filesystem backend](https://reference.langchain.com/python/deepagents/backends/filesystem/FilesystemBackend) to the agent. Set up a folder and make it available to the agent. This and other backend systems are discussed [here](https://docs.langchain.com/oss/python/deepagents/backends).

# %% [markdown]
# ⚠️**Security Warning**⚠️
#
# This backend grants agents direct filesystem read/write access. Use with caution and only in appropriate environments.
#
# Appropriate use cases:
#
# - Local development CLIs (coding assistants, development tools)
# - CI/CD pipelines (see security considerations below)
#
# Inappropriate use cases:
#
# - Web servers or HTTP APIs - use StateBackend, StoreBackend, or SandboxBackend instead
#
# Security risks:
#
# - Agents can read any accessible file, including secrets (API keys, credentials, .env files)
# - Combined with network tools, secrets may be exfiltrated via SSRF attacks
# - File modifications are permanent and irreversible
#
# Recommended safeguards:
#
# - Enable Human-in-the-Loop (HITL) middleware to review sensitive operations
# - Exclude secrets from accessible filesystem paths (especially in CI/CD)
# - For production environments, prefer StateBackend, StoreBackend or SandboxBackend
#
# In general, we expect this backend to be used with Human-in-the-Loop (HITL) middleware, or within a properly sandboxed environment if you need to run untrusted workloads.
#
# In addition, instead of writing to your file system's backend, you could write to other backends in the cloud, databases (e.g. SQL) etc

# %%
agent_files_path = "./agent_files" #the path will be created in ./01_materials/labs
os.makedirs(agent_files_path, exist_ok=True) # Create the directory if it doesn't exist; if it already exists do nothing 
filesystem = FilesystemBackend(root_dir=agent_files_path, virtual_mode=True)

# %% [markdown]
# Set permissions: `interrupt` when a `write` operation is attempted. Apply this to all (`"/**"`) paths.

# %%
permission = FilesystemPermission( #if you hover over FilesystemPermission, you'll see that the default value of mode is "allow"...
    operations=["write"],
    paths=["/**"],
    mode="interrupt",  #... so you need to overwrite that and set mode to "interrupt" in order to establish the checkpoint 
)

# %% [markdown]
# When an interruption occurs, we will need to store the entire state of the graph in Memory. This is a checkpoint, implemented below.

# %%
checkpointer = MemorySaver()

# %% [markdown]
# Finally, we create the agent based on the components defined above:
#
# - Model
# - Tools: internet search
# - Permissions
# - Checkpoint memory
# - Filesystem backend
#
# With the below code chunk you have effectively done everything in notebook 07_1_llm_compiler, but automatically without all that effort! (the tradeoff is control over specs)

# %%
agent = create_deep_agent(
    model=llm,
    tools=[internet_search],
    permissions=[permission], #interrupt when trying to write
    checkpointer=checkpointer, #when interrupted, save state with MemorySaver 
    backend=filesystem,
)

print("Agent constructed:", agent is not None)
# Out:
# Agent constructed: True

# %%
agent

# %% [markdown]
# The above mermaid diagram shows what the model looks like.

# %% [markdown]
# ## Section 3 - Research Loop: Approve Path
#
# Run the agent with a research topic. It will search the web, then **pause** and ask for permission before writing results to disk.
#
# The two-cell pattern below is the pedagogical center of this notebook:
# - **Cell A - Invoke**: agent runs until it hits the write gate, execution suspends, `result.interrupts` is non-empty
# - **Cell B - Resume**: you send a decision, agent continues from where it stopped
#
# We guide the agent's save path with a filename hint in the prompt (OQ2 resolution).

# %%
topic = "recent advances in retrieval-augmented generation"
config = {"configurable": {"thread_id": "research-1"}} #have used more complicated thread ids, like the unique identifier uuid, in past notebooks

prompt = f"Research this topic and save a summary to rag_research.md: {topic}"
result = agent.invoke(
    {"messages": [("user", prompt)]},
    config=config,
    version="v2",
)

pending = len(result.interrupts) if result.interrupts else 0
print(f"Invoke complete. Interrupts pending: {pending}")
# Out:
# Invoke complete. Interrupts pending: 1

# %%
#can also see this by running: 
result
# Out:
# GraphOutput(value={'messages': [HumanMessage(content='Research this topic and save a summary to rag_research.md: recent advances in retrieval-augmented generation', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 5373, 'total_tokens': 5445, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a17b1ca31d', 'id': 'chatcmpl-E1PzsasoWGvemYZSkWZl9nFbBU7Fg', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f5f19-f99c-7a81-a413-a08030e1004d-0', tool_calls=[{'name': 'task', 'args': {'description': "Research recent advances in retrieval-augmented generation, focusing on notable methodologies, applications, and contributions in this area. Summarize key findings and insights in a concise format suitable for documentation. The summary should be saved to a file named 'rag_research.md'.", 'subagent_type': 'general-purpose'}, 'id': 'call_C2HiUVXrScgiOsPV24hIXvzX', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 5373, 'output_tokens': 72, 'total_tokens': 5445, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Tool call task with id call_C2HiUVXrScgiOsPV24hIXvzX was cancelled - another message came in before it could be completed.', name='task', tool_call_id='call_C2HiUVXrScgiOsPV24hIXvzX'), HumanMessage(content='Research this topic and save a summary to rag_research.md: recent advances in retrieval-augmented generation', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 5511, 'total_tokens': 5583, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a17b1ca31d', 'id': 'chatcmpl-E1QdA7NNSahtJmYzHRTO5aFU8xZzD', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f5f3f-26dc-7600-aa45-9e0a333b6414-0', tool_calls=[{'name': 'task', 'args': {'description': "Research recent advances in retrieval-augmented generation, focusing on notable methodologies, applications, and contributions in this area. Summarize key findings and insights in a concise format suitable for documentation. The summary should be saved to a file named 'rag_research.md'.", 'subagent_type': 'general-purpose'}, 'id': 'call_K1rJa0D1JUfWAJwowCPGGLex', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 5511, 'output_tokens': 72, 'total_tokens': 5583, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'files': {}}, interrupts=(Interrupt(value={'action_requests': [{'name': 'write_file', 'args': {'file_path': '/rag_research.md', 'content': '# Recent Advances in Retrieval-Augmented Generation (RAG)\n\n## Overview\nRetrieval-Augmented Generation (RAG) is a significant advancement in natural language processing (NLP), combining large language models (LLMs) and information retrieval systems to improve the accuracy and contextual relevance of generated text. The following sections highlight notable methodologies, applications, and contributions in this area.\n\n## Methodologies\n1. **Hybrid Approaches**: RAG systems typically merge a neural retriever with a generator, grounding outputs in external documents — notably implemented in the seminal work by Lewis et al. (2020) wit ...

# %% [markdown]
# The agent stopped before writing. Inspect what it wants to do, then decide.

# %%
# Inspect the pending write request
if result.interrupts:
    interrupt_value = result.interrupts[0].value
    action_requests = interrupt_value.get("action_requests", [])
    if action_requests:
        req = action_requests[0]
        file_path = req['args']['file_path']
        content = req['args']['content']
        display(Markdown("**Agent wants to write:**"))
        display(Markdown(f"**Path:** {file_path}"))
        content = str(content)
        preview = content[:400] + "...\n"
        display(Markdown(f"**Preview:**\n\n{preview}"))
    else:
        display(Markdown(f"**Interrupt payload:** {interrupt_value}"))
else:
    display(Markdown("**Agent completed without requesting a write - no interrupt to inspect.**"))
    display(Markdown("**This can happen if the agent decided the results did not warrant saving.**"))
    display(Markdown("**Skip to Section 5 to run the self-assessment.**"))
# Out:
# **Agent wants to write:**
# **Path:** /rag_research.md
# **Preview:**
#
# # Recent Advances in Retrieval-Augmented Generation (RAG)
#
# ## Overview
# Retrieval-Augmented Generation (RAG) is a significant advancement in natural language processing (NLP), combining large language models (LLMs) and information retrieval systems to improve the accuracy and contextual relevance of generated text. The following sections highlight notable methodologies, applications, and contributi...

# %%
# Approve - let's say you show this preview to the user and the user has approved this output. send the approve decision to the agent, so that the agent resumes and writes the file
approved_result = agent.invoke(
    Command(resume={"decisions": [{"type": "approve"}]}),
    config=config,
    version="v2",
)

# Normalize for Section 5 - last_result holds the most recent completed run
last_result = approved_result

# Show the agent's final AI message
msgs = last_result["messages"] if isinstance(last_result, dict) else last_result.value['messages']
final_msg = next(
    (m for m in reversed(msgs) if isinstance(m, AIMessage) and not getattr(m, "tool_calls", None)),
    None
)
if final_msg:
    print("Agent final message:")
    print(final_msg.content)
# Out:
# Agent final message:
# The summary of recent advances in retrieval-augmented generation (RAG) has been saved in `rag_research.md`. Here are the key sections:
#
# ### Recent Advances in Retrieval-Augmented Generation (RAG)
#
# #### Overview
# RAG combines large language models (LLMs) and information retrieval systems to enhance the contextual relevance of generated text.
#
# #### Methodologies
# 1. **Hybrid Approaches**: Merges neural retrievers with generators, notably using BART by Lewis et al. (2020).
# 2. **Multimodal Integration**: Incorporates text, images, and videos for cross-modal retrieval.
# 3. **Domain-Specific Enhancements**: Introduces strategies like Hybrid Parameter-Adaptive (HyPA-RAG) for specialized applications.
# 4. **Chunking and Embedding Techniques**: Emphasizes segmenting inputs and selecting appropriate embedding models.
#
# #### Applications
# 1. **Dialogue Generation**: Improves conversational agents with contextually accurate responses.
# 2. **Machine Translation**: Enhances translation services by integrating relevant information.
# 3. **Enterprise Systems**: Used in resume screening and recruitment automation.
#
# #### Key Contributions
# - Systematic reviews mapping RAG progress and suggesting future research directions.
# - Innovations presented in recent conferences (e.g., SIGIR 2022).
#
# #### Future Directions
# - Exploring RAG effectiveness across various settings.
# - Addressing security and privacy challenges in sensitive areas like healthcare.
#
# #### Conclusion
# RAG is vital for NLP applications, combining real-time retrieval with natural language generation for enhanced performance across different domains.
#
# You can refer to the file for a detailed read.

# %%
# Verify the file was written
saved_path = os.path.join(agent_files_path, "rag_research.md")
if os.path.exists(saved_path):
    print(f"File written: {saved_path} ({os.path.getsize(saved_path)} bytes)")
else:
    nearby_md = [f for f in os.listdir(agent_files_path) if f.endswith(".md")]
    if nearby_md:
        print("Markdown files found nearby:", nearby_md)
    else:
        print("No markdown file found in current directory.")
        print("The agent may have written to a different path - check the content preview above.")
# Out:
# File written: ./agent_files/rag_research.md (3087 bytes)

# %% [markdown]
# Remove files before starting next section.

# %%
import shutil
shutil.rmtree(agent_files_path)

# %% [markdown]
# ## Section 4 - Research Loop: Reject Path
#
# The reject path uses a **fresh `thread_id`** so it starts with a clean state - no bleed from the approve run above.
#
# When you reject, the agent:
# - Skips the file write entirely (R6)
# - Acknowledges your decision in its final message
# - Does **not** retry - the loop ends after one rejection

# %%
# Fresh thread_id - independent session, no state from Section 3
config_reject = {"configurable": {"thread_id": "research-2"}}

prompt_reject = f"Research this topic and save a summary to rag_research_reject.md: {topic}"
result_reject = agent.invoke(
    {"messages": [("user", prompt_reject)]},
    config=config_reject,
    version="v2",
)

pending_r = len(result_reject.interrupts) if result_reject.interrupts else 0
display(Markdown(f"Invoke complete. Interrupts pending: {pending_r}"))
# Out:
# Invoke complete. Interrupts pending: 1

# %%
# Inspect the pending write (same pattern as Section 3)
if result.interrupts:
    interrupt_value = result.interrupts[0].value
    action_requests = interrupt_value.get("action_requests", [])
    if action_requests:
        req = action_requests[0]
        file_path = req['args']['file_path']
        content = req['args']['content']
        display(Markdown("**Agent wants to write:**"))
        display(Markdown(f"**Path:** {file_path}"))
        content = str(content)
        preview = content[:400] + "...\n"
        display(Markdown(f"**Preview:**\n\n{preview}"))
    else:
        display(Markdown(f"**Interrupt payload:** {interrupt_value}"))
else:
    display(Markdown("**Agent completed without requesting a write - no interrupt to inspect.**"))
    display(Markdown("**This can happen if the agent decided the results did not warrant saving.**"))
    display(Markdown("**Skip to Section 5 to run the self-assessment.**"))
# Out:
# **Agent wants to write:**
# **Path:** /rag_research.md
# **Preview:**
#
# # Recent Advances in Retrieval-Augmented Generation (RAG)
#
# ## Key Developments in RAG
# 1. **Enhanced Architectures**: Recent research has focused on enhancing transformer architectures that integrate retrieval mechanisms, improving the ability to access extensive data without requiring massive model parameters.
#
# 2. **Fine-Tuning Techniques**: Advances in transfer learning and fine-tuning specific...

# %%
# Reject - agent skips the write and acknowledges
rejected_result = agent.invoke(
    Command(resume={"decisions": [{"type": "reject", "message": "User declined the save."}]}),
    config=config_reject,
    version="v2",
)

# Normalize for Section 5 - overwrite last_result with the reject-path result
last_result = rejected_result

msgs_r = last_result["messages"] if isinstance(last_result, dict) else last_result.value['messages']
final_msg_r = next(
    (m for m in reversed(msgs_r) if isinstance(m, AIMessage) and not getattr(m, "tool_calls", None)),
    None
)
if final_msg_r:
    print("Agent acknowledged rejection:")
    print(final_msg_r.content)

# %%
# Confirm no file was written

if os.path.exists(saved_path):
    print("Unexpected: file was written despite rejection.")
else:
    print("Confirmed: no file written after rejection.")
# Out:
# Confirmed: no file written after rejection.

# %% [markdown]
# ## Section 5 - Quality Self-Assessment
#
# The self-assessment runs **regardless of whether you approved or rejected the write**. It evaluates the *search result quality* - not the file write decision.
#
# This cell reads `last_result`, which was set at the end of Section 3 (approve) or Section 4 (reject), whichever you ran most recently. Run both sections to compare how the assessment behaves after each path.
#
# > **Why a standalone LLM call?** The evaluation is intentionally outside the agent graph - simpler to teach, and it runs identically after both paths. In production, you would add this as a post-interrupt node in the graph.

# %%
# Extract the agent's final AI message from the most recent run
msgs_final = last_result["messages"] if isinstance(last_result, dict) else last_result.value['messages']
ai_messages = [m for m in msgs_final if isinstance(m, AIMessage)]
agent_final_message = ai_messages[-1].content if ai_messages else "(no AI message found in result)"

# Build the assessment prompt using string concatenation (avoids triple-quote complexity)
assessment_prompt = (
    f'Assess the following research result for the topic: "{topic}"\n\n'
    f'Result:\n{agent_final_message}\n\n'
    'Evaluate:\n'
    '1. Does the result directly address the topic? (Yes / Partially / No)\n'
    '2. What key aspects of the topic are missing or only partially covered?\n'
    '3. Overall coverage rating: High / Medium / Low - one sentence of justification.'
)

assessment_messages = [{"role": "user", "content": assessment_prompt}]
assessment = llm.invoke(assessment_messages)
display(Markdown("###  Quality Self-Assessment"))
display(Markdown(assessment.content))
# Out:
# ###  Quality Self-Assessment
# 1. **Does the result directly address the topic?**: Yes
#
# 2. **What key aspects of the topic are missing or only partially covered?**: While the result provides a good overview of methodologies, applications, and future directions, it lacks depth in discussing the underlying mechanisms of retrieval-augmented generation, such as specific algorithms or architectures beyond BART, and it does not elaborate on performance metrics or benchmarks in the field.
#
# 3. **Overall coverage rating**: Medium - the result effectively outlines key methodologies and applications but could benefit from a more detailed exploration of technical implementations and empirical evaluations.
